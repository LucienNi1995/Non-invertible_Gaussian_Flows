# %%
import torch
import torch.nn as nn
import torch.distributions as D
import math
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os

# %%
def Gaussian_integral2(z,mu,sigma,base_sigma,k_dim=3,pi=math.pi):
    c=-torch.matmul(sigma.t()[0],sigma.t()[1:].inverse())
    h=torch.matmul(z-mu,sigma.t()[1:].inverse())
    a=(1+c**2).sum()/(2*base_sigma)
    b=(-c*h).sum(1)/base_sigma
    m=(-h**2).sum(1)/(2*base_sigma)
    return (pi/(a*(2*base_sigma*pi)**k_dim)).sqrt()*(m+b**2/(4*a)).exp()

# %%
# --------------------
# Flow
# --------------------
class PlanarTransform(nn.Module):
    def __init__(self, init_sigma=0.01):
        super().__init__()
        self.u = nn.Parameter(torch.randn(1, 2).normal_(0, init_sigma))
        self.w = nn.Parameter(torch.randn(1, 2).normal_(0, init_sigma))
        self.b = nn.Parameter(torch.randn(1).fill_(0))

    def forward(self, x, normalize_u=True):
        # allow for a single forward pass over all the transforms in the flows with a Sequential container
        if isinstance(x, tuple):
            z, sum_log_abs_det_jacobians = x
        else:
            z, sum_log_abs_det_jacobians = x, 0

        # normalize u s.t. w @ u >= -1; sufficient condition for invertibility
        u_hat = self.u
        if normalize_u:
            wtu = (self.w @ self.u.t()).squeeze()
            m_wtu = - 1 + torch.log1p(wtu.exp())
            u_hat = self.u + (m_wtu - wtu) * self.w / (self.w @ self.w.t())

        # compute transform
        f_z = z + u_hat * torch.tanh(z @ self.w.t() + self.b)
        # compute log_abs_det_jacobian
        psi = (1 - torch.tanh(z @ self.w.t() + self.b)**2) @ self.w
        det = 1 + psi @ u_hat.t()
        log_abs_det_jacobian = torch.log(torch.abs(det) + 1e-6).squeeze()
        sum_log_abs_det_jacobians = sum_log_abs_det_jacobians + log_abs_det_jacobian

        return f_z, sum_log_abs_det_jacobians

class AffineTransform(nn.Module):
    def __init__(self, learnable=True):
        super().__init__()
        self.mu = nn.Parameter(torch.zeros(2)).requires_grad_(learnable)
        self.sigma = nn.Parameter(torch.ones(2, 3).normal_(0, 1)).requires_grad_(learnable)
    def forward(self, x):
        z = torch.tanh(self.mu + torch.matmul(x,self.sigma.t()))
        ab=1-torch.tanh(self.mu+torch.matmul(x,self.sigma.t()))**2
        sum_log_abs_det_jacobians = torch.log((((ab[:,0]*ab[:,1])**2*(self.sigma@self.sigma.t()).det()).abs())**0.5*Gaussian_integral2(torch.atanh(z),self.mu,self.sigma,args.base_sigma))
        return z, sum_log_abs_det_jacobians

# %%
# --------------------
# Training
# --------------------

def optimize_flow(base_dist, flow, target_energy_potential, optimizer, args):

    # anneal rate for free energy
    temp = lambda i: min(1, 0.01 + i/10000)

    for i in range(args.start_step, args.n_steps):

        # sample base dist
        z = base_dist.sample((args.batch_size, )).to(args.device)

        # pass through flow:
        # 1. compute expected log_prob of data under base dist -- nothing tied to parameters here so irrelevant to grads
        base_log_prob = base_dist.log_prob(z)
        # 2. compute sum of log_abs_det_jacobian through the flow
        zk, sum_log_abs_det_jacobians = flow(z)
        # 3. compute expected log_prob of z_k the target_energy potential
        p_log_prob = - temp(i) * target_energy_potential(zk)  # p = exp(-potential) ==> p_log_prob = - potential

        loss = base_log_prob - sum_log_abs_det_jacobians - args.beta * p_log_prob
        loss = loss.mean(0)

        # compute loss and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if i % 10000 == 0:
            # display loss
            log_qk = base_dist.log_prob(z) - sum_log_abs_det_jacobians
            print('{}: step {:5d} / {}; loss {:.3f}; base_log_prob {:.3f}, sum log dets {:.3f}, p_log_prob {:.3f}, max base = {:.3f}; max qk = {:.3f} \
                zk_mean {}, zk_sigma {}; base_mu {}, base_log_sigma {}'.format(
                args.target_potential, i, args.n_steps, loss.item(), base_log_prob.mean(0).item(), sum_log_abs_det_jacobians.mean(0).item(),
                p_log_prob.mean(0).item(), base_log_prob.exp().max().item(), log_qk.exp().max().item(),
                zk.mean(0).cpu().data.numpy(), zk.var(0).sqrt().cpu().data.numpy(),
                base_dist.loc.cpu().data.numpy() if not args.learn_base else flow[0].mu.cpu().data.numpy(),
                base_dist.covariance_matrix.cpu().diag().data.numpy() if not args.learn_base else flow[0].sigma.cpu().data.numpy()))

            # save model
            torch.save({'step': i,
                        'flow_state': flow.state_dict(),
                        'optimizer_state': optimizer.state_dict()},
                        os.path.join(args.output_dir, 'model_state_flow_length_{}.pt'.format(args.flow_length)))

            # plot and save results
            with torch.no_grad():
                plot_flow2(base_dist, flow, os.path.join(args.output_dir, 'approximating_flow_step{}.png'.format(i)), args)

# %%
# --------------------
# Plotting
# --------------------

def plot_flow2(base_dist, flow, filename, args):
    n = 100
    lim = 4
    limx=4
    fig, axs = plt.subplots(1, 2, subplot_kw={'aspect': 'equal'})

    # plot flow-transformed base dist sample and histogram
    z = base_dist.sample((10000,))
    zk, _ = flow(z)
    zk = zk.cpu().data.numpy()
    axs[0].scatter(zk[:,0], zk[:,1], s=10, alpha=0.4)
    axs[1].hist2d(zk[:,0], zk[:,1], bins=[limx*50,lim*50], range = [[-4,4],[-4,4]], cmap=plt.cm.jet)

    for ax in plt.gcf().axes:
        ax.set_xlim(-4, 4)
        ax.set_ylim(-4, 4)
        ax.get_xaxis().set_visible(True)
        ax.get_yaxis().set_visible(True)
        ax.invert_yaxis()

    plt.tight_layout()
    plt.savefig(filename)
    plt.close()

# %%
# --------------------
# Plotting
# --------------------

def plot_flow(base_dist, flow, filename, args):
    n = 200
    lim = 4
    limx=4
    z = base_dist.sample((10000,))
    fig, axs = plt.subplots(1, 2, subplot_kw={'aspect': 'equal'})
    zz = z.cpu().data.numpy()
    axs[0].scatter(zz[:,0], zz[:,1], s=10, alpha=0.4)
    axs[1].hist2d(zz[:,0], zz[:,1], bins=[limx*50,lim*50], range = [[-4,4],[-4,4]], cmap=plt.cm.jet)
    for ax in plt.gcf().axes:
        ax.set_xlim(-4, 4)
        ax.set_ylim(-4, 4)
        ax.get_xaxis().set_visible(True)
        ax.get_yaxis().set_visible(True)
        ax.invert_yaxis()

    plt.tight_layout()
    plt.savefig(filename+'_0.png')
    plt.close()
    # plot target density we're trying to approx
    # plot_target_density(u_z, axs[0,0], lim, n)

    # plot posterior approx density
    # plot_flow_density(base_dist, flow, axs[0,1], lim, n)

    # plot flow-transformed base dist sample and histogram
    for i in range(1,34):
        fig, axs = plt.subplots(1, 2, subplot_kw={'aspect': 'equal'})

        zk, _ = flow[0:i](z)
        zk = zk.cpu().data.numpy()
        axs[0].scatter(zk[:,0], zk[:,1], s=10, alpha=0.4)
        axs[1].hist2d(zk[:,0], zk[:,1], bins=[limx*50,lim*50], range = [[-4,4],[-4,4]], cmap=plt.cm.jet)

        for ax in plt.gcf().axes:
            ax.set_xlim(-4, 4)
            ax.set_ylim(-4, 4)
            ax.get_xaxis().set_visible(True)
            ax.get_yaxis().set_visible(True)
            ax.invert_yaxis()

        plt.tight_layout()
        plt.savefig(filename+'_%d.png'%i)
        plt.close()

# %%
def plot_target_density(u_z, ax,  n=200, output_dir=None):
    x1 = torch.linspace(-4, 4, n)
    x2 = torch.linspace(-4, 4, n)
    xx, yy = torch.meshgrid((x1, x2))
    zz = torch.stack((xx.flatten(), yy.flatten()), dim=-1).squeeze().to(args.device)
    xx=xx.cpu()
    yy=yy.cpu()
    zz=zz.cpu()
    ax.pcolormesh(xx, yy, torch.exp(-u_z(zz)).view(n,n).data, cmap=plt.cm.jet)

    for ax in plt.gcf().axes:
        ax.set_xlim(-4, 4)
        ax.set_ylim(-4, 4)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax.invert_yaxis()

    if output_dir:
        plt.tight_layout()
        plt.savefig(os.path.join(output_dir, 'target_potential_density.png'))
        plt.close()

# %%
def plot_flow_density(base_dist, flow, ax, range_lim=4, n=100, output_dir=None):
    x = torch.linspace(-range_lim, range_lim, n)
    xx, yy,hh= torch.meshgrid((x, x, x))
    zz = torch.stack((xx.flatten(), yy.flatten(),hh.flatten()), dim=-1).squeeze().to(args.device)
    # plot posterior approx density
    zzk, sum_log_abs_det_jacobians = flow(zz)
    log_q0 = base_dist.log_prob(zz)
    log_qk = log_q0 - sum_log_abs_det_jacobians
    qk = log_qk.exp().cpu()
    zzk = zzk.cpu()
    n1=1000
    ax.pcolormesh(zzk[:,0].view(n1,n1).data, zzk[:,1].view(n1,n1).data, qk.view(n1,n1).data, cmap=plt.cm.jet)
    ax.set_facecolor(plt.cm.jet(0.))

    for ax in plt.gcf().axes:
        ax.set_xlim(-range_lim, range_lim)
        ax.set_ylim(-range_lim, range_lim)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax.invert_yaxis()

    if output_dir:
        plt.tight_layout()
        plt.savefig(os.path.join(output_dir, 'flow_k{}_density.png'.format(len(flow)-1)))
        plt.close()

# %%
w1 = lambda z: torch.sin(2 * math.pi * z[:,0] / 4)
w2 = lambda z: 3 * torch.exp(-0.5 * ((z[:,0] - 1)/0.6)**2)
w3 = lambda z: 3 * torch.sigmoid((z[:,0] - 1) / 0.3)

u_z1 = lambda z: 0.5 * ((torch.norm(z, p=2, dim=1) - 2) / 0.4)**2 - \
                 torch.log(torch.exp(-0.5*((z[:,0] - 2) / 0.6)**2) + torch.exp(-0.5*((z[:,0] + 2) / 0.6)**2) + 1e-10)
u_z2 = lambda z: 0.5 * ((z[:,1] - w1(z)) / 0.4)**2
u_z3 = lambda z: - torch.log(torch.exp(-0.5*((z[:,1] - w1(z))/0.35)**2) + torch.exp(-0.5*((z[:,1] - w1(z) + w2(z))/0.35)**2) + 1e-10)
u_z4 = lambda z: - torch.log(torch.exp(-0.5*((z[:,1] - w1(z))/0.4)**2) + torch.exp(-0.5*((z[:,1] - w1(z) + w3(z))/0.35)**2) + 1e-10)

# %%
# --------------------
# Run
# --------------------
class args:
    # actions
    use_cuda=True                                          # whether to use cuda 
    restore_file=0 # Path to model to restore.
    output_dir='./results_test_v1_u_z1_k8' # Path to output folder.
    train=True # Train a flow.
    evaluate=True # Evaluate a flow
    plot=True # Plot a flow and target density.

    # flow params
    learn_base=True # Whether to learn a mu-sigma affine transform of the base distribution.
    flow_length=8 # Length of the flow.
    base_sigma=1.0 # Std of the base isotropic 0-mean Gaussian distribution.

    # target potential
    target_potential='u_z1' # Which potential function to approximate.

    # training params
    seed=2 # Random seed
    init_sigma=1.0 #Initialization std for the trainable flow parameters.
    batch_size=100 # batch size in training
    start_step=0 # Starting step (if resuming training will be overwrite from filename).
    n_steps=1000000 # Optimization steps.
    lr= 1e-5 # Learning rate.
    weight_decay= 1e-3 # Weight decay.
    beta=1.0 # Multiplier for the target potential loss.

# %%
# cuda to device
args.device = torch.device('cuda:0' if torch.cuda.is_available() and args.use_cuda else 'cpu')

# set up random seed
torch.manual_seed(args.seed)
if args.device.type == 'cuda': torch.cuda.manual_seed(args.seed)

# setup flow
flow = nn.Sequential(AffineTransform(args.learn_base), *[PlanarTransform(args.init_sigma) for _ in range(args.flow_length)]).to(args.device)

# setup target potential to approx
u_z = vars()[args.target_potential]

# setup base distribution
base_dist = D.MultivariateNormal(torch.zeros(3).to(args.device), args.base_sigma * torch.eye(3).to(args.device))

if args.restore_file:
    # get filename
    filename = os.path.basename(args.restore_file)
    args.flow_length = int(filename.partition('length_')[-1].rpartition('.')[0])
    # reset output dir
    args.output_dir = os.path.dirname(args.restore_file)
    # load state
    state = torch.load(args.restore_file, map_location=args.device)
    # compatibility code;
    # 1/ earlier models did not include step and optimizer checkpoints;
    try:
        flow_state = state['flow_state']
        optimizer_state = state['optimizer_state']
        args.start_step = state['step']
    except KeyError:
        # if state is not a dict, load just the model state
        flow_state = state
        optimizer_state = None
    # 2/ some saved checkpoints may not have a first affine layer
    try:
        flow_state['0.mu']
    except KeyError:
        # if no first affine layer, reload a flow model without one
        flow = nn.Sequential(*[PlanarTransform(args.init_sigma) for _ in range(args.flow_length)])
    flow.load_state_dict(flow_state)

# %%
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

# %%
if args.train:
    optimizer = torch.optim.RMSprop(flow.parameters(), lr=args.lr, momentum=0.9, alpha=0.90, eps=1e-6, weight_decay=args.weight_decay)
    if args.restore_file and optimizer_state:
        optimizer.load_state_dict(optimizer_state)
    args.n_steps = args.start_step + args.n_steps
    optimize_flow(base_dist, flow, u_z, optimizer, args)
# Out:
# u_z1: step     0 / 1000000; loss 5.305; base_log_prob -4.281, sum log dets -9.488, p_log_prob -0.098, max base = 0.062; max qk = 66246.328                 zk_mean [-0.00331786 -0.01490544], zk_sigma [0.11861719 0.8653099 ]; base_mu [3.1620839e-05 3.1622192e-05], base_log_sigma [[ 0.3922652  -0.22359563 -0.3195319 ]
#  [-1.2050055   1.0444951  -0.63319606]]
# u_z1: step 10000 / 1000000; loss 0.571; base_log_prob -4.215, sum log dets -3.822, p_log_prob -0.964, max base = 0.059; max qk = 271.385                 zk_mean [0.07963513 0.28907505], zk_sigma [1.7675805 1.227759 ]; base_mu [ 0.05309679 -0.00628944], base_log_sigma [[ 0.05176254 -0.23796894 -0.25815788]
#  [-0.73695076  1.0661451  -0.5905199 ]]
# u_z1: step 20000 / 1000000; loss 0.235; base_log_prob -4.335, sum log dets -3.634, p_log_prob -0.935, max base = 0.062; max qk = 117.086                 zk_mean [-0.1608651  -0.01909245], zk_sigma [1.8013389 1.2371475]; base_mu [ 0.03075872 -0.02851705], base_log_sigma [[ 0.04223323 -0.23921771 -0.23032296]
#  [-0.557014    1.0458026  -0.6083906 ]]
# u_z1: step 30000 / 1000000; loss 0.068; base_log_prob -4.201, sum log dets -3.497, p_log_prob -0.772, max base = 0.063; max qk = 12.997                 zk_mean [0.04517015 0.24130644], zk_sigma [1.8034037 1.1997635]; base_mu [ 0.02983969 -0.00244825], base_log_sigma [[ 0.03089531 -0.23103729 -0.21632674]
#  [-0.43350568  1.0480806  -0.60911673]]
# u_z1: step 40000 / 1000000; loss 0.078; base_log_prob -4.397, sum log dets -3.630, p_log_prob -0.846, max base = 0.060; max qk = 7.476                 zk_mean [0.0368901  0.20124817], zk_sigma [1.8645413 1.1811382]; base_mu [ 0.02739646 -0.00666376], base_log_sigma [[ 0.02564921 -0.21441807 -0.20627704]
#  [-0.34711242  1.0291827  -0.6219885 ]]
# u_z1: step 50000 / 1000000; loss -0.095; base_log_prob -4.201, sum log dets -3.343, p_log_prob -0.762, max base = 0.061; max qk = 18.548                 zk_mean [0.19534598 0.18566301], zk_sigma [1.7914002 1.1654576]; base_mu [ 0.0195976  -0.00954603], base_log_sigma [[ 0.01577882 -0.208401   -0.20940465]
#  [-0.27983096  0.99679023 -0.6405378 ]]
# u_z1: step 60000 / 1000000; loss 0.248; base_log_prob -4.355, sum log dets -3.671, p_log_prob -0.931, max base = 0.061; max qk = 22.178                 zk_mean [0.05556287 0.0069271 ], zk_sigma [1.7401506 1.2973974]; base_mu [0.02488017 0.00389407], base_log_sigma [[ 0.00940501 -0.19100465 -0.19779935]
#  [-0.22006512  0.98776245 -0.6337897 ]]
# u_z1: step 70000 / 1000000; loss 0.058; base_log_prob -4.162, sum log dets -3.501, p_log_prob -0.720, max base = 0.061; max qk = 5.714                 zk_mean [0.05667422 0.18029144], zk_sigma [1.8431638 1.1423156]; base_mu [0.02218158 0.00916507], base_log_sigma [[ 0.00476716 -0.1851399  -0.19490609]
#  [-0.17159575  0.96814424 -0.63529074]]
# u_z1: step 80000 / 1000000; loss -0.156; base_log_prob -4.268, sum log dets -3.372, p_log_prob -0.739, max base = 0.058; max qk = 5.163                 zk_mean [-0.09444495 -0.02237611], zk_sigma [1.8375505 1.0586084]; base_mu [0.0259013  0.03949482], base_log_sigma [[ 0.00265336 -0.17619155 -0.19746825]
#  [-0.13594975  0.93906134 -0.6439929 ]]
# u_z1: step 90000 / 1000000; loss -0.040; base_log_prob -4.364, sum log dets -3.542, p_log_prob -0.781, max base = 0.060; max qk = 17.242                 zk_mean [-0.23817652  0.1663158 ], zk_sigma [1.839117  1.2078916]; base_mu [0.02127129 0.0374651 ], base_log_sigma [[ 0.00245471 -0.17784268 -0.2000948 ]
#  [-0.10596197  0.88742054 -0.67332494]]
# u_z1: step 100000 / 1000000; loss -0.127; base_log_prob -4.218, sum log dets -3.392, p_log_prob -0.699, max base = 0.059; max qk = 10.703                 zk_mean [-0.45501718  0.124526  ], zk_sigma [1.8313864 1.1684492]; base_mu [0.02000103 0.04011397], base_log_sigma [[-0.00107484 -0.17354548 -0.19311932]
#  [-0.08693639  0.86540055 -0.6739395 ]]
# u_z1: step 110000 / 1000000; loss 0.044; base_log_prob -4.182, sum log dets -3.456, p_log_prob -0.771, max base = 0.057; max qk = 3.659                 zk_mean [-0.2083312  -0.18210508], zk_sigma [1.9069871 1.0810789]; base_mu [0.02198175 0.06094761], base_log_sigma [[-0.00105498 -0.1643138  -0.18608887]
#  [-0.0588378   0.8606548  -0.6601925 ]]
# u_z1: step 120000 / 1000000; loss -0.289; base_log_prob -4.190, sum log dets -3.335, p_log_prob -0.566, max base = 0.060; max qk = 2.240                 zk_mean [0.12310501 0.2776751 ], zk_sigma [1.8313026 1.1020337]; base_mu [0.0199974  0.06369502], base_log_sigma [[-0.00398234 -0.1629551  -0.1820259 ]
#  [-0.03888     0.8359177  -0.6647341 ]]
# u_z1: step 130000 / 1000000; loss -0.245; base_log_prob -4.115, sum log dets -3.261, p_log_prob -0.609, max base = 0.062; max qk = 1.961                 zk_mean [-0.1087422   0.10938049], zk_sigma [1.8631155 1.009132 ]; base_mu [0.01922817 0.06497212], base_log_sigma [[-0.00257249 -0.16808216 -0.18198986]
#  [-0.03370684  0.8094671  -0.6736551 ]]
# u_z1: step 140000 / 1000000; loss -0.041; base_log_prob -4.366, sum log dets -3.485, p_log_prob -0.840, max base = 0.058; max qk = 13.368                 zk_mean [ 0.10617355 -0.10861016], zk_sigma [1.7236913 1.2749115]; base_mu [0.0144943  0.06468001], base_log_sigma [[-0.00096894 -0.16619736 -0.17558818]
#  [-0.02274155  0.7917985  -0.6763352 ]]
# u_z1: step 150000 / 1000000; loss -0.105; base_log_prob -4.127, sum log dets -3.362, p_log_prob -0.660, max base = 0.062; max qk = 3.956                 zk_mean [-0.17887287 -0.12045328], zk_sigma [1.86752  1.115469]; base_mu [0.01253446 0.06605221], base_log_sigma [[ 0.00250589 -0.16857898 -0.16790503]
#  [-0.02117016  0.77958965 -0.674955  ]]
# u_z1: step 160000 / 1000000; loss 0.261; base_log_prob -4.403, sum log dets -3.741, p_log_prob -0.922, max base = 0.063; max qk = 7.674                 zk_mean [-0.45109248 -0.04863299], zk_sigma [1.7430224 1.2758209]; base_mu [0.01271091 0.06625991], base_log_sigma [[-0.00139527 -0.174363   -0.17087632]
#  [-0.0245175   0.7491991  -0.69173265]]
# u_z1: step 170000 / 1000000; loss -0.121; base_log_prob -4.279, sum log dets -3.492, p_log_prob -0.666, max base = 0.058; max qk = 4.499                 zk_mean [-0.02387607  0.00709195], zk_sigma [1.8201982 1.1364487]; base_mu [0.01156402 0.0727621 ], base_log_sigma [[ 6.6459342e-04 -1.7907234e-01 -1.6940442e-01]
#  [-1.2109131e-02  7.2043520e-01 -7.0621705e-01]]
# u_z1: step 180000 / 1000000; loss 0.049; base_log_prob -4.497, sum log dets -3.709, p_log_prob -0.837, max base = 0.058; max qk = 3.172                 zk_mean [-0.04886009 -0.01544469], zk_sigma [1.8043092 1.1866654]; base_mu [0.00992321 0.06449507], base_log_sigma [[ 0.00362402 -0.179159   -0.16240172]
#  [-0.00665455  0.7101893  -0.70614594]]
# u_z1: step 190000 / 1000000; loss 0.015; base_log_prob -4.352, sum log dets -3.572, p_log_prob -0.795, max base = 0.057; max qk = 7.771                 zk_mean [ 0.22475086 -0.09408401], zk_sigma [1.8485788 1.11209  ]; base_mu [0.00801083 0.05915587], base_log_sigma [[ 6.1786786e-04 -1.7694785e-01 -1.5560040e-01]
#  [-1.5397085e-02  6.9437563e-01 -7.1140206e-01]]
# u_z1: step 200000 / 1000000; loss 0.206; base_log_prob -4.566, sum log dets -3.847, p_log_prob -0.926, max base = 0.060; max qk = 26.334                 zk_mean [-0.23394918  0.02574321], zk_sigma [1.7701108 1.2467082]; base_mu [0.00919862 0.07631528], base_log_sigma [[-1.3218919e-04 -1.8526636e-01 -1.5851679e-01]
#  [-2.6044080e-03  6.7762285e-01 -7.1527237e-01]]
# u_z1: step 210000 / 1000000; loss -0.239; base_log_prob -4.216, sum log dets -3.236, p_log_prob -0.741, max base = 0.060; max qk = 4.299                 zk_mean [ 0.02940689 -0.21938106], zk_sigma [1.9220687 0.9959332]; base_mu [0.01458253 0.08572956], base_log_sigma [[-0.00210244 -0.18928641 -0.15491715]
#  [-0.00556423  0.65639144 -0.7250239 ]]
# u_z1: step 220000 / 1000000; loss -0.127; base_log_prob -4.143, sum log dets -3.305, p_log_prob -0.711, max base = 0.061; max qk = 7.968                 zk_mean [-0.27684388  0.10683981], zk_sigma [1.7923901 1.0329995]; base_mu [0.01247534 0.08895625], base_log_sigma [[-0.00103039 -0.19298077 -0.15175553]
#  [-0.01098589  0.6280179  -0.74269366]]
# u_z1: step 230000 / 1000000; loss -0.021; base_log_prob -4.316, sum log dets -3.513, p_log_prob -0.783, max base = 0.056; max qk = 6.016                 zk_mean [-0.24554965  0.02634255], zk_sigma [1.9087613 1.169074 ]; base_mu [0.01233318 0.09205064], base_log_sigma [[-1.7899962e-04 -1.9787292e-01 -1.4955540e-01]
#  [-9.3234889e-03  5.9172738e-01 -7.6639646e-01]]
# u_z1: step 240000 / 1000000; loss -0.083; base_log_prob -4.085, sum log dets -3.303, p_log_prob -0.698, max base = 0.062; max qk = 5.962                 zk_mean [-0.13818343 -0.06056272], zk_sigma [1.8413215 1.1441455]; base_mu [0.02008898 0.10173717], base_log_sigma [[ 0.0023586  -0.20501262 -0.14923397]
#  [-0.00480302  0.56505436 -0.7784302 ]]
# u_z1: step 250000 / 1000000; loss -0.314; base_log_prob -4.086, sum log dets -3.077, p_log_prob -0.695, max base = 0.062; max qk = 1.221                 zk_mean [-0.34778044 -0.1892285 ], zk_sigma [1.8335922 1.0625098]; base_mu [0.01505426 0.09957404], base_log_sigma [[ 0.00346693 -0.20840478 -0.14203598]
#  [-0.01459955  0.5455912  -0.7876265 ]]
# u_z1: step 260000 / 1000000; loss -0.117; base_log_prob -4.363, sum log dets -3.473, p_log_prob -0.773, max base = 0.063; max qk = 2.300                 zk_mean [0.08061635 0.01505086], zk_sigma [1.8430763 1.1435547]; base_mu [0.01454239 0.09879281], base_log_sigma [[ 0.0011693  -0.2129714  -0.13774234]
#  [-0.00387211  0.530068   -0.7959593 ]]
# u_z1: step 270000 / 1000000; loss -0.204; base_log_prob -4.062, sum log dets -3.141, p_log_prob -0.717, max base = 0.060; max qk = 2.243                 zk_mean [-0.19811389 -0.15812808], zk_sigma [1.8302433 1.1163954]; base_mu [0.01919746 0.10337932], base_log_sigma [[ 0.00211711 -0.21035771 -0.13406818]
#  [-0.00983488  0.5108334  -0.80189204]]
# u_z1: step 280000 / 1000000; loss 0.143; base_log_prob -4.450, sum log dets -3.588, p_log_prob -1.006, max base = 0.063; max qk = 7.169                 zk_mean [-0.19285709  0.20198415], zk_sigma [1.8143514 1.2464917]; base_mu [0.02310805 0.10834102], base_log_sigma [[ 7.27210077e-04 -2.09982678e-01 -1.24946535e-01]
#  [-6.34557893e-03  4.97636229e-01 -8.04117262e-01]]
# u_z1: step 290000 / 1000000; loss -0.159; base_log_prob -4.214, sum log dets -3.205, p_log_prob -0.850, max base = 0.060; max qk = 3.582                 zk_mean [ 0.08743641 -0.12807359], zk_sigma [1.7871226 1.2460573]; base_mu [0.01938377 0.10909701], base_log_sigma [[ 0.00191544 -0.2288047  -0.12925787]
#  [-0.00651156  0.45311025 -0.8337142 ]]
# u_z1: step 300000 / 1000000; loss -0.076; base_log_prob -4.254, sum log dets -3.386, p_log_prob -0.793, max base = 0.062; max qk = 4.500                 zk_mean [-0.15821058  0.14476947], zk_sigma [1.8874464 1.0816513]; base_mu [0.01707804 0.1039897 ], base_log_sigma [[ 0.00326424 -0.23304418 -0.11866393]
#  [-0.01480884  0.42818034 -0.846847  ]]
# u_z1: step 310000 / 1000000; loss -0.118; base_log_prob -4.260, sum log dets -3.223, p_log_prob -0.919, max base = 0.062; max qk = 2.127                 zk_mean [-0.19389585 -0.16946596], zk_sigma [1.8213016 1.1254287]; base_mu [0.01506874 0.10216941], base_log_sigma [[-3.3565296e-04 -2.3944487e-01 -1.1300312e-01]
#  [-1.0436819e-02  4.0099391e-01 -8.6140281e-01]]
# u_z1: step 320000 / 1000000; loss -0.113; base_log_prob -4.127, sum log dets -3.297, p_log_prob -0.717, max base = 0.060; max qk = 4.993                 zk_mean [-0.11691613 -0.01414822], zk_sigma [1.8355707 1.161949 ]; base_mu [0.00695695 0.0930054 ], base_log_sigma [[ 2.79293832e-04 -2.49408469e-01 -1.05777405e-01]
#  [-7.39218527e-03  3.64466071e-01 -8.84477973e-01]]
# u_z1: step 330000 / 1000000; loss 0.209; base_log_prob -4.349, sum log dets -3.688, p_log_prob -0.871, max base = 0.060; max qk = 4.766                 zk_mean [-0.1367276  -0.07384046], zk_sigma [1.756317  1.1571765]; base_mu [0.00903452 0.0869517 ], base_log_sigma [[ 2.1356276e-04 -2.4265929e-01 -9.8539159e-02]
#  [-2.6664550e-03  3.5868326e-01 -8.7892717e-01]]
# u_z1: step 340000 / 1000000; loss -0.079; base_log_prob -4.231, sum log dets -3.390, p_log_prob -0.763, max base = 0.060; max qk = 7.548                 zk_mean [-0.03029675 -0.09876915], zk_sigma [1.8629131 1.2177091]; base_mu [0.01082841 0.09232368], base_log_sigma [[ 0.0019247  -0.2431529  -0.09577402]
#  [ 0.01132475  0.33865985 -0.881913  ]]
# u_z1: step 350000 / 1000000; loss -0.167; base_log_prob -4.191, sum log dets -3.317, p_log_prob -0.707, max base = 0.061; max qk = 1.821                 zk_mean [-0.08018896  0.11447711], zk_sigma [1.7940279 1.0319813]; base_mu [0.01866063 0.09822679], base_log_sigma [[-8.6280209e-04 -2.4898681e-01 -9.6439302e-02]
#  [ 2.5628097e-03  3.0326352e-01 -8.9772129e-01]]
# u_z1: step 360000 / 1000000; loss -0.132; base_log_prob -4.134, sum log dets -3.234, p_log_prob -0.767, max base = 0.060; max qk = 2.687                 zk_mean [ 0.13375416 -0.06867038], zk_sigma [1.8573893 1.1197385]; base_mu [0.01263953 0.09498175], base_log_sigma [[ 0.0014216  -0.253439   -0.08679517]
#  [ 0.00583905  0.27870125 -0.9038953 ]]
# u_z1: step 370000 / 1000000; loss 0.045; base_log_prob -4.264, sum log dets -3.456, p_log_prob -0.853, max base = 0.063; max qk = 4.845                 zk_mean [0.07902737 0.13144372], zk_sigma [1.7574674 1.2277658]; base_mu [0.00447927 0.08720513], base_log_sigma [[-2.4821071e-04 -2.5447211e-01 -7.9781257e-02]
#  [-3.5206105e-03  2.5813335e-01 -9.0961736e-01]]
# u_z1: step 380000 / 1000000; loss 0.138; base_log_prob -4.443, sum log dets -3.720, p_log_prob -0.861, max base = 0.063; max qk = 2.374                 zk_mean [-0.19544035  0.15822943], zk_sigma [1.802694  1.1869721]; base_mu [0.00725145 0.08198932], base_log_sigma [[ 6.3707063e-04 -2.6317114e-01 -7.7247046e-02]
#  [ 3.2815046e-03  2.2311321e-01 -9.2160219e-01]]
# u_z1: step 390000 / 1000000; loss -0.155; base_log_prob -4.220, sum log dets -3.350, p_log_prob -0.715, max base = 0.062; max qk = 4.298                 zk_mean [-0.13312161  0.00232605], zk_sigma [1.800822  1.1139164]; base_mu [0.00947976 0.08388482], base_log_sigma [[-0.00317221 -0.264451   -0.07080666]
#  [ 0.01893202  0.19376458 -0.92198867]]
# u_z1: step 400000 / 1000000; loss -0.207; base_log_prob -4.130, sum log dets -3.168, p_log_prob -0.754, max base = 0.060; max qk = 1.918                 zk_mean [-0.27673435 -0.01756897], zk_sigma [1.9095651 1.1361327]; base_mu [-0.00147093  0.07347554], base_log_sigma [[ 0.00154801 -0.27303645 -0.06288943]
#  [ 0.02821929  0.16377161 -0.9277923 ]]
# u_z1: step 410000 / 1000000; loss 0.230; base_log_prob -4.312, sum log dets -3.596, p_log_prob -0.946, max base = 0.058; max qk = 4.372                 zk_mean [-0.1771471   0.07350478], zk_sigma [1.8009242 1.3592287]; base_mu [-0.00621035  0.07028797], base_log_sigma [[-0.00096559 -0.28058776 -0.05284011]
#  [ 0.01773196  0.1316216  -0.92833656]]
# u_z1: step 420000 / 1000000; loss -0.042; base_log_prob -4.436, sum log dets -3.544, p_log_prob -0.851, max base = 0.063; max qk = 2.126                 zk_mean [-0.09621515 -0.14995022], zk_sigma [1.8262043 1.1194268]; base_mu [-0.00100021  0.07556941], base_log_sigma [[ 0.00273638 -0.27985445 -0.04877601]
#  [ 0.00706963  0.09724643 -0.923596  ]]
# u_z1: step 430000 / 1000000; loss -0.180; base_log_prob -4.144, sum log dets -3.133, p_log_prob -0.830, max base = 0.063; max qk = 2.186                 zk_mean [-0.01152204 -0.09227866], zk_sigma [1.8337153 1.1209768]; base_mu [0.01169813 0.08227273], base_log_sigma [[ 6.4995722e-04 -2.7977940e-01 -4.9433514e-02]
#  [ 1.1493801e-02  7.1544714e-02 -9.0619332e-01]]
# u_z1: step 440000 / 1000000; loss -0.033; base_log_prob -4.214, sum log dets -3.236, p_log_prob -0.945, max base = 0.060; max qk = 1.816                 zk_mean [ 0.07782192 -0.18851526], zk_sigma [1.7865093 1.1340721]; base_mu [0.00706918 0.08195245], base_log_sigma [[ 7.3092541e-04 -2.7742437e-01 -4.3416336e-02]
#  [ 1.5219944e-02  6.0675401e-02 -8.9767444e-01]]
# u_z1: step 450000 / 1000000; loss -0.295; base_log_prob -4.269, sum log dets -3.235, p_log_prob -0.739, max base = 0.061; max qk = 3.503                 zk_mean [-0.04545517 -0.07871994], zk_sigma [1.9089583 1.0642204]; base_mu [-0.00619173  0.07796751], base_log_sigma [[ 0.00400585 -0.28204408 -0.0364572 ]
#  [ 0.02638679  0.03760729 -0.8927572 ]]
# u_z1: step 460000 / 1000000; loss -0.215; base_log_prob -4.166, sum log dets -3.186, p_log_prob -0.765, max base = 0.063; max qk = 3.390                 zk_mean [0.03840749 0.15497312], zk_sigma [1.8623018 1.2552269]; base_mu [0.00713432 0.0800785 ], base_log_sigma [[-0.00155809 -0.28661752 -0.0424663 ]
#  [ 0.02834545  0.0055141  -0.8755781 ]]
# u_z1: step 470000 / 1000000; loss 0.097; base_log_prob -4.583, sum log dets -3.673, p_log_prob -1.006, max base = 0.052; max qk = 5.875                 zk_mean [0.11464071 0.07181658], zk_sigma [1.7363174 1.1833864]; base_mu [0.01802646 0.08462793], base_log_sigma [[ 5.4149143e-04 -3.0240354e-01 -3.9542411e-02]
#  [ 1.3702754e-02 -3.4750089e-02 -8.5499889e-01]]
# u_z1: step 480000 / 1000000; loss -0.073; base_log_prob -4.181, sum log dets -3.327, p_log_prob -0.782, max base = 0.059; max qk = 14.711                 zk_mean [-0.3478485   0.05326441], zk_sigma [1.7569035 1.1932069]; base_mu [0.02123601 0.08954056], base_log_sigma [[ 0.00330204 -0.3052614  -0.02885399]
#  [ 0.01543857 -0.06274029 -0.8337059 ]]
# u_z1: step 490000 / 1000000; loss -0.028; base_log_prob -4.170, sum log dets -3.345, p_log_prob -0.798, max base = 0.061; max qk = 1.973                 zk_mean [-0.2186661  0.1753178], zk_sigma [1.867079  1.0555079]; base_mu [-0.00402832  0.07871322], base_log_sigma [[-0.0016731  -0.3145496  -0.00976524]
#  [ 0.01604513 -0.09655879 -0.81727415]]
# u_z1: step 500000 / 1000000; loss -0.002; base_log_prob -4.290, sum log dets -3.484, p_log_prob -0.804, max base = 0.058; max qk = 4.822                 zk_mean [0.10457468 0.10483903], zk_sigma [1.8464705 1.1368701]; base_mu [-0.00277722  0.07548711], base_log_sigma [[ 1.2084914e-03 -3.2025921e-01  1.5484008e-04]
#  [ 2.1358397e-02 -1.3111384e-01 -7.9044753e-01]]
# u_z1: step 510000 / 1000000; loss -0.007; base_log_prob -4.149, sum log dets -3.364, p_log_prob -0.779, max base = 0.061; max qk = 2.945                 zk_mean [ 0.04837798 -0.2347672 ], zk_sigma [1.8751402 1.0550375]; base_mu [-0.01055128  0.06959295], base_log_sigma [[-0.00137736 -0.3366043   0.01710832]
#  [ 0.00976533 -0.16933867 -0.7586839 ]]
# u_z1: step 520000 / 1000000; loss -0.051; base_log_prob -4.201, sum log dets -3.410, p_log_prob -0.740, max base = 0.060; max qk = 2.285                 zk_mean [-0.05802754  0.1376181 ], zk_sigma [1.8506441 1.0753294]; base_mu [-0.00920054  0.06721471], base_log_sigma [[-0.00247938 -0.32778174  0.02213959]
#  [ 0.01815441 -0.19050257 -0.7412003 ]]
# u_z1: step 530000 / 1000000; loss -0.222; base_log_prob -4.415, sum log dets -3.301, p_log_prob -0.891, max base = 0.062; max qk = 2.550                 zk_mean [-0.47734466 -0.18975912], zk_sigma [1.761158 1.193822]; base_mu [0.02523749 0.08003337], base_log_sigma [[-0.00096485 -0.32884413  0.02256669]
#  [ 0.00814947 -0.21088506 -0.71975917]]
# u_z1: step 540000 / 1000000; loss -0.019; base_log_prob -4.446, sum log dets -3.664, p_log_prob -0.763, max base = 0.061; max qk = 4.902                 zk_mean [-0.33432952 -0.08232532], zk_sigma [1.7670796 1.2009132]; base_mu [0.02642535 0.08630197], base_log_sigma [[ 0.00783288 -0.3497392   0.03853036]
#  [ 0.01890858 -0.2483818  -0.6882868 ]]
# u_z1: step 550000 / 1000000; loss -0.160; base_log_prob -4.227, sum log dets -3.266, p_log_prob -0.800, max base = 0.062; max qk = 2.058                 zk_mean [-0.1151996 -0.0893238], zk_sigma [1.8052619 1.1588693]; base_mu [0.03557678 0.09180821], base_log_sigma [[ 0.00461769 -0.34936708  0.05348154]
#  [ 0.01322561 -0.27574196 -0.66219556]]
# u_z1: step 560000 / 1000000; loss -0.086; base_log_prob -4.321, sum log dets -3.386, p_log_prob -0.849, max base = 0.063; max qk = 4.916                 zk_mean [-0.24870355  0.14126357], zk_sigma [1.7831606 1.2634059]; base_mu [0.01793947 0.08268744], base_log_sigma [[ 0.00802226 -0.33943322  0.05866697]
#  [ 0.01383721 -0.2949476  -0.6460738 ]]
# u_z1: step 570000 / 1000000; loss -0.110; base_log_prob -4.182, sum log dets -3.407, p_log_prob -0.665, max base = 0.060; max qk = 6.714                 zk_mean [-0.18078558  0.09866476], zk_sigma [1.8009129 1.1551516]; base_mu [-0.00467751  0.07291733], base_log_sigma [[ 0.00760637 -0.3678839   0.09872311]
#  [ 0.02381318 -0.34133846 -0.6029173 ]]
# u_z1: step 580000 / 1000000; loss 0.224; base_log_prob -4.287, sum log dets -3.569, p_log_prob -0.942, max base = 0.057; max qk = 5.888                 zk_mean [ 0.08187893 -0.0984848 ], zk_sigma [1.7649144 1.2066997]; base_mu [0.00128137 0.07324257], base_log_sigma [[ 0.01004884 -0.37085727  0.11592674]
#  [ 0.02412215 -0.37306955 -0.57101154]]
# u_z1: step 590000 / 1000000; loss -0.021; base_log_prob -4.281, sum log dets -3.505, p_log_prob -0.754, max base = 0.060; max qk = 2.331                 zk_mean [-0.3009882   0.00786517], zk_sigma [1.8503991 1.1810292]; base_mu [-0.01131443  0.06684719], base_log_sigma [[ 0.00212735 -0.36021054  0.12669115]
#  [ 0.02526379 -0.3928884  -0.55286777]]
# u_z1: step 600000 / 1000000; loss -0.004; base_log_prob -4.384, sum log dets -3.481, p_log_prob -0.899, max base = 0.062; max qk = 2.467                 zk_mean [-0.15431666  0.09225289], zk_sigma [1.8184481 1.2404001]; base_mu [-0.00824588  0.06678661], base_log_sigma [[-0.00426924 -0.3674651   0.1569579 ]
#  [ 0.01163562 -0.42972183 -0.5148849 ]]
# u_z1: step 610000 / 1000000; loss -0.212; base_log_prob -4.254, sum log dets -3.392, p_log_prob -0.650, max base = 0.061; max qk = 3.050                 zk_mean [ 0.0149283  -0.08547001], zk_sigma [1.834513  1.0900996]; base_mu [-0.01794416  0.05873934], base_log_sigma [[-0.00435699 -0.36947438  0.1885653 ]
#  [-0.002205   -0.46918884 -0.47373268]]
# u_z1: step 620000 / 1000000; loss -0.094; base_log_prob -4.300, sum log dets -3.461, p_log_prob -0.745, max base = 0.062; max qk = 5.069                 zk_mean [-0.3300224   0.17673492], zk_sigma [1.7707992 1.1879835]; base_mu [-0.02507381  0.05304953], base_log_sigma [[-0.00491418 -0.35459965  0.1997818 ]
#  [-0.00985577 -0.49198225 -0.45084274]]
# u_z1: step 630000 / 1000000; loss 0.066; base_log_prob -4.341, sum log dets -3.559, p_log_prob -0.849, max base = 0.059; max qk = 2.470                 zk_mean [-0.14103155  0.16846892], zk_sigma [1.8135729 1.2586881]; base_mu [-0.02967075  0.04777455], base_log_sigma [[-0.0077046  -0.34887186  0.21904416]
#  [-0.01933011 -0.52024585 -0.4203864 ]]
# u_z1: step 640000 / 1000000; loss -0.051; base_log_prob -4.256, sum log dets -3.392, p_log_prob -0.813, max base = 0.063; max qk = 2.100                 zk_mean [-0.07534485  0.07880979], zk_sigma [1.7912838 1.2011073]; base_mu [-0.03384254  0.04227633], base_log_sigma [[-0.00730594 -0.34081352  0.24435225]
#  [-0.02174187 -0.55357057 -0.38357705]]
# u_z1: step 650000 / 1000000; loss -0.315; base_log_prob -4.170, sum log dets -3.201, p_log_prob -0.654, max base = 0.057; max qk = 2.044                 zk_mean [0.11215908 0.10523996], zk_sigma [1.8675265 1.1454183]; base_mu [-0.02561359  0.04677001], base_log_sigma [[-0.01111621 -0.32688478  0.2594103 ]
#  [-0.02498346 -0.5758275  -0.3569306 ]]
# u_z1: step 660000 / 1000000; loss -0.473; base_log_prob -4.139, sum log dets -2.967, p_log_prob -0.699, max base = 0.061; max qk = 1.940                 zk_mean [-0.38613167 -0.14076449], zk_sigma [1.7337127 1.133186 ]; base_mu [-0.02405958  0.04555817], base_log_sigma [[-0.0049601  -0.30926964  0.27661586]
#  [-0.02247509 -0.60140973 -0.32687843]]
# u_z1: step 670000 / 1000000; loss -0.133; base_log_prob -4.402, sum log dets -3.493, p_log_prob -0.776, max base = 0.061; max qk = 2.823                 zk_mean [-0.11595375 -0.1703345 ], zk_sigma [1.7806917 1.2453959]; base_mu [-0.01735527  0.04955297], base_log_sigma [[-0.00326072 -0.29948032  0.29517606]
#  [-0.02086691 -0.626638   -0.2949667 ]]
# u_z1: step 680000 / 1000000; loss -0.066; base_log_prob -4.383, sum log dets -3.533, p_log_prob -0.783, max base = 0.063; max qk = 15.422                 zk_mean [-0.4089696  -0.16909084], zk_sigma [1.7932924 1.040774 ]; base_mu [-0.01946585  0.04667046], base_log_sigma [[-0.00118665 -0.28569973  0.31279483]
#  [-0.01511537 -0.64763325 -0.26506642]]
# u_z1: step 690000 / 1000000; loss 0.102; base_log_prob -4.351, sum log dets -3.525, p_log_prob -0.928, max base = 0.063; max qk = 5.273                 zk_mean [-0.15111153 -0.00448522], zk_sigma [1.7487265 1.278871 ]; base_mu [0.0001395  0.05896296], base_log_sigma [[ 0.0013361  -0.26358876  0.3397306 ]
#  [-0.00776963 -0.6626938  -0.22395913]]
# u_z1: step 700000 / 1000000; loss -0.180; base_log_prob -4.182, sum log dets -3.307, p_log_prob -0.696, max base = 0.060; max qk = 9.027                 zk_mean [-0.28788757 -0.14550889], zk_sigma [1.7859865 1.0908859]; base_mu [0.00629697 0.06389129], base_log_sigma [[-0.00355505 -0.23753126  0.35425028]
#  [-0.01069356 -0.6627074  -0.19303676]]
# u_z1: step 710000 / 1000000; loss -0.158; base_log_prob -4.200, sum log dets -3.277, p_log_prob -0.765, max base = 0.062; max qk = 2.598                 zk_mean [-0.18944515 -0.00741501], zk_sigma [1.7622758 1.2165381]; base_mu [0.02100159 0.07316168], base_log_sigma [[-0.00414732 -0.21826409  0.3507985 ]
#  [-0.01114822 -0.65581095 -0.17686372]]
# u_z1: step 720000 / 1000000; loss -0.232; base_log_prob -4.780, sum log dets -3.699, p_log_prob -0.849, max base = 0.056; max qk = 3.944                 zk_mean [0.03598848 0.08076081], zk_sigma [1.8178239 1.2339991]; base_mu [0.01310708 0.06843002], base_log_sigma [[ 0.00223052 -0.21082112  0.37997577]
#  [-0.00543004 -0.6502645  -0.13608979]]
# u_z1: step 730000 / 1000000; loss -0.028; base_log_prob -4.353, sum log dets -3.523, p_log_prob -0.802, max base = 0.060; max qk = 9.169                 zk_mean [-0.29043618  0.14108136], zk_sigma [1.8532367 1.1802619]; base_mu [0.01715114 0.07279794], base_log_sigma [[ 0.00567839 -0.19314378  0.39666146]
#  [ 0.00200406 -0.6293616  -0.10427439]]
# u_z1: step 740000 / 1000000; loss 0.121; base_log_prob -4.383, sum log dets -3.579, p_log_prob -0.925, max base = 0.063; max qk = 5.061                 zk_mean [-0.2587609   0.18898956], zk_sigma [1.8238088 1.2824411]; base_mu [0.01053196 0.06721067], base_log_sigma [[-4.4994013e-04 -1.8485793e-01  3.9704734e-01]
#  [-4.7066184e-03 -6.1645019e-01 -8.7594241e-02]]
# u_z1: step 750000 / 1000000; loss -0.155; base_log_prob -4.255, sum log dets -3.391, p_log_prob -0.710, max base = 0.059; max qk = 3.335                 zk_mean [-0.23126803  0.10480539], zk_sigma [1.8400167 1.1583564]; base_mu [0.02321025 0.0736564 ], base_log_sigma [[-5.7369709e-04 -1.7471547e-01  4.0698862e-01]
#  [-6.9009438e-03 -5.9643900e-01 -6.3239634e-02]]
# u_z1: step 760000 / 1000000; loss 0.033; base_log_prob -4.315, sum log dets -3.409, p_log_prob -0.939, max base = 0.061; max qk = 2.224                 zk_mean [-0.28896806  0.00055838], zk_sigma [1.8110445 1.2122018]; base_mu [0.00895314 0.06324389], base_log_sigma [[-0.00644983 -0.14465623  0.44114918]
#  [-0.01272091 -0.5638897  -0.02235049]]
# u_z1: step 770000 / 1000000; loss -0.010; base_log_prob -4.322, sum log dets -3.605, p_log_prob -0.707, max base = 0.060; max qk = 5.999                 zk_mean [-0.24003725 -0.0871392 ], zk_sigma [1.7972938 1.2179848]; base_mu [0.01204506 0.06773438], base_log_sigma [[ 1.0651357e-04 -1.3252456e-01  4.4981325e-01]
#  [-3.4684718e-03 -5.4268545e-01  6.2060135e-04]]
# u_z1: step 780000 / 1000000; loss -0.235; base_log_prob -4.052, sum log dets -3.131, p_log_prob -0.687, max base = 0.054; max qk = 2.730                 zk_mean [0.14642751 0.15929627], zk_sigma [1.9552147 1.0315286]; base_mu [-0.00172031  0.05786049], base_log_sigma [[ 0.00673413 -0.12110896  0.4614836 ]
#  [ 0.00470337 -0.52669376  0.0222772 ]]
# u_z1: step 790000 / 1000000; loss -0.081; base_log_prob -4.262, sum log dets -3.332, p_log_prob -0.850, max base = 0.058; max qk = 1.845                 zk_mean [-0.50727606 -0.01949276], zk_sigma [1.7560283 1.1820344]; base_mu [0.02488539 0.07481713], base_log_sigma [[ 0.0180092  -0.12087244  0.45063704]
#  [ 0.01943717 -0.5195297   0.02529412]]
# u_z1: step 800000 / 1000000; loss -0.079; base_log_prob -4.189, sum log dets -3.316, p_log_prob -0.794, max base = 0.062; max qk = 4.259                 zk_mean [-0.1404677 -0.042362 ], zk_sigma [1.8184472 1.2578092]; base_mu [0.03235192 0.07789855], base_log_sigma [[ 0.01328064 -0.10722159  0.4587719 ]
#  [ 0.01696979 -0.50165343  0.04458403]]
# u_z1: step 810000 / 1000000; loss -0.009; base_log_prob -4.312, sum log dets -3.585, p_log_prob -0.718, max base = 0.059; max qk = 3.402                 zk_mean [ 0.08449844 -0.12675062], zk_sigma [1.8294034 1.1260161]; base_mu [0.03522399 0.0803404 ], base_log_sigma [[ 0.00215829 -0.09435547  0.4632934 ]
#  [ 0.00444452 -0.485134    0.05813178]]
# u_z1: step 820000 / 1000000; loss -0.172; base_log_prob -4.096, sum log dets -3.282, p_log_prob -0.642, max base = 0.062; max qk = 8.950                 zk_mean [-0.4069062   0.03476237], zk_sigma [1.7753718 1.1159407]; base_mu [0.03796084 0.07997184], base_log_sigma [[-0.00382118 -0.06811052  0.4820082 ]
#  [-0.00221681 -0.45876637  0.08241533]]
# u_z1: step 830000 / 1000000; loss -0.320; base_log_prob -4.060, sum log dets -3.087, p_log_prob -0.653, max base = 0.056; max qk = 2.903                 zk_mean [0.01240292 0.06400556], zk_sigma [1.817567  1.1876562]; base_mu [0.04225435 0.08234293], base_log_sigma [[-0.01612919 -0.06156203  0.47918558]
#  [-0.01777729 -0.45017046  0.08806849]]
# u_z1: step 840000 / 1000000; loss 0.029; base_log_prob -4.014, sum log dets -3.354, p_log_prob -0.688, max base = 0.058; max qk = 4.177                 zk_mean [-0.26026765  0.36140308], zk_sigma [1.8460729 1.0416154]; base_mu [0.04611923 0.0849337 ], base_log_sigma [[-0.01131303 -0.04829808  0.48230115]
#  [-0.01069277 -0.43622687  0.09904698]]
# u_z1: step 850000 / 1000000; loss 0.058; base_log_prob -4.323, sum log dets -3.623, p_log_prob -0.758, max base = 0.059; max qk = 3.185                 zk_mean [-0.42881012 -0.12811746], zk_sigma [1.7301583 1.1502717]; base_mu [0.03527191 0.07748128], base_log_sigma [[-0.01271983 -0.04471269  0.48337695]
#  [-0.01240379 -0.42981738  0.10650551]]
# u_z1: step 860000 / 1000000; loss -0.082; base_log_prob -4.140, sum log dets -3.316, p_log_prob -0.742, max base = 0.060; max qk = 3.140                 zk_mean [-0.322752  -0.2832629], zk_sigma [1.8286164 1.0444634]; base_mu [0.02853674 0.07164432], base_log_sigma [[-0.01048762 -0.02555591  0.49716276]
#  [-0.01019888 -0.40937898  0.12526593]]
# u_z1: step 870000 / 1000000; loss 0.150; base_log_prob -4.186, sum log dets -3.396, p_log_prob -0.941, max base = 0.060; max qk = 6.702                 zk_mean [-0.4397013 -0.0886663], zk_sigma [1.7554867 1.2138337]; base_mu [0.03737465 0.07708567], base_log_sigma [[-0.00463268 -0.00087277  0.5124949 ]
#  [-0.00432601 -0.38696918  0.14346737]]
# u_z1: step 880000 / 1000000; loss -0.031; base_log_prob -4.305, sum log dets -3.379, p_log_prob -0.894, max base = 0.062; max qk = 3.006                 zk_mean [-0.36019546 -0.11016086], zk_sigma [1.7398081 1.2137573]; base_mu [0.0488712  0.08393079], base_log_sigma [[-0.00132696  0.02848268  0.5248102 ]
#  [-0.00091611 -0.36194217  0.16083814]]
# u_z1: step 890000 / 1000000; loss -0.093; base_log_prob -4.285, sum log dets -3.339, p_log_prob -0.854, max base = 0.061; max qk = 3.958                 zk_mean [-0.31734166  0.06519225], zk_sigma [1.7223064 1.2504374]; base_mu [0.05779422 0.08832368], base_log_sigma [[-0.01469963  0.03670571  0.5199403 ]
#  [-0.01290459 -0.35520652  0.16396217]]
# u_z1: step 900000 / 1000000; loss -0.131; base_log_prob -4.245, sum log dets -3.422, p_log_prob -0.691, max base = 0.056; max qk = 6.531                 zk_mean [-0.51290023  0.13886179], zk_sigma [1.7532514 1.135192 ]; base_mu [0.06053676 0.08844384], base_log_sigma [[-0.00592889  0.05153979  0.5215371 ]
#  [-0.00323749 -0.34298447  0.17171352]]
# u_z1: step 910000 / 1000000; loss 0.063; base_log_prob -4.222, sum log dets -3.527, p_log_prob -0.757, max base = 0.062; max qk = 4.560                 zk_mean [-0.21832411  0.13540357], zk_sigma [1.7952591 1.2484376]; base_mu [0.05779791 0.08544539], base_log_sigma [[-0.01074907  0.05993968  0.52438015]
#  [-0.00794953 -0.3354577   0.17974779]]
# u_z1: step 920000 / 1000000; loss 0.060; base_log_prob -4.168, sum log dets -3.391, p_log_prob -0.837, max base = 0.062; max qk = 3.609                 zk_mean [-0.20565566  0.01333853], zk_sigma [1.8053536 1.1609211]; base_mu [0.06357428 0.08745122], base_log_sigma [[-0.00642789  0.07691799  0.5274711 ]
#  [-0.00378557 -0.32191977  0.188202  ]]
# u_z1: step 930000 / 1000000; loss -0.322; base_log_prob -4.108, sum log dets -3.089, p_log_prob -0.697, max base = 0.062; max qk = 2.877                 zk_mean [-0.08578131  0.09177707], zk_sigma [1.8680621 1.1420859]; base_mu [0.05726384 0.0826539 ], base_log_sigma [[-2.1959846e-03  1.0049900e-01  5.3857046e-01]
#  [-1.6432662e-04 -3.0355635e-01  2.0108594e-01]]
# u_z1: step 940000 / 1000000; loss -0.230; base_log_prob -4.271, sum log dets -3.248, p_log_prob -0.792, max base = 0.057; max qk = 1.928                 zk_mean [-0.29413393  0.00918755], zk_sigma [1.8296534 1.1947671]; base_mu [0.05812756 0.0825597 ], base_log_sigma [[ 4.72969732e-05  1.13323204e-01  5.35797000e-01]
#  [ 1.54469872e-03 -2.94511467e-01  2.03979701e-01]]
# u_z1: step 950000 / 1000000; loss -0.128; base_log_prob -4.105, sum log dets -3.238, p_log_prob -0.739, max base = 0.058; max qk = 7.124                 zk_mean [-0.05816743 -0.00116296], zk_sigma [1.8252183 1.216642 ]; base_mu [0.04851269 0.07459955], base_log_sigma [[ 0.00248908  0.12464108  0.53635144]
#  [ 0.00514046 -0.2857112   0.20976584]]
# u_z1: step 960000 / 1000000; loss 0.052; base_log_prob -4.247, sum log dets -3.460, p_log_prob -0.839, max base = 0.055; max qk = 9.190                 zk_mean [-0.2501088   0.03267602], zk_sigma [1.7573918 1.3268301]; base_mu [0.05922616 0.08169563], base_log_sigma [[ 0.01267571  0.14021477  0.53152704]
#  [ 0.01255316 -0.2720978   0.21452563]]
# u_z1: step 970000 / 1000000; loss 0.204; base_log_prob -4.323, sum log dets -3.656, p_log_prob -0.872, max base = 0.056; max qk = 8.162                 zk_mean [-0.04089195  0.14384697], zk_sigma [1.7338015 1.3105416]; base_mu [0.04466955 0.07334946], base_log_sigma [[ 0.00580852  0.16428843  0.5370909 ]
#  [ 0.00385907 -0.25479475  0.22001007]]
# u_z1: step 980000 / 1000000; loss -0.130; base_log_prob -4.362, sum log dets -3.396, p_log_prob -0.836, max base = 0.059; max qk = 6.012                 zk_mean [-0.16538773 -0.04408518], zk_sigma [1.7762735 1.2705085]; base_mu [0.0467268  0.07238954], base_log_sigma [[ 0.00443009  0.18000272  0.5304032 ]
#  [ 0.0031748  -0.24345054  0.22073485]]
# u_z1: step 990000 / 1000000; loss -0.281; base_log_prob -4.315, sum log dets -3.277, p_log_prob -0.757, max base = 0.059; max qk = 4.574                 zk_mean [-0.10026556 -0.02663189], zk_sigma [1.7537441 1.2473073]; base_mu [0.04792536 0.07383863], base_log_sigma [[ 0.01006287  0.20626698  0.519308  ]
#  [ 0.00615541 -0.22455096  0.21365494]]

# %%
if args.evaluate:
    plot_flow(base_dist, flow, os.path.join(args.output_dir, 'approximating_flow'), args)

# %%
if args.plot:
    plot_target_density(u_z, plt.gca(), output_dir=args.output_dir)
    plot_flow_density(base_dist, flow, plt.gca(), output_dir=args.output_dir)
